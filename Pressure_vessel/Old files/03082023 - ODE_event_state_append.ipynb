# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import constants 
from scipy.interpolate import CubicSpline
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
import pandas as pd
import seaborn as sns
import itertools

# %%
# Load weather data 

# specify the file path (use the actual path on your system)
file_path = 'Meteo_data/Weather_data_2023_7_8_n1.csv'

# read the CSV file into a DataFrame
df = pd.read_csv(file_path) #Data in seconds, T in K and P in Pa, windspeed in m/s, 0.1 meter above the ground

# Set time period
n_days = int(file_path[-5]) #Extract how many days are simulated in the file
df
# Out:
#             T_amb          P_amb    v_wind  P_sun
# 0      292.200000  101790.000000  1.141151    0.0
# 1      292.199833  101789.988889  1.141151    0.0
# 2      292.199667  101789.977778  1.141151    0.0
# 3      292.199500  101789.966667  1.141151    0.0
# 4      292.199333  101789.955556  1.141151    0.0
# ...           ...            ...       ...    ...
# 86396  296.400000  101710.000000  1.033567    0.0
# 86397  296.400000  101710.000000  1.033567    0.0
# 86398  296.400000  101710.000000  1.033567    0.0
# 86399  296.400000  101710.000000  1.033567    0.0
# 86400  296.400000  101710.000000  1.033567    0.0
#
# [86401 rows x 4 columns]

# %% [markdown]
# Simulation variables

# %%
#Vessel variables
#rho_vessel = 2.7e3 # aluminium [kg/m3]
rho_vessel = 1.455e3 # Pet [kg/m3] Source: https://plasticranger.com/density-of-pet-plastic/#:~:text=The%20density%20of%20PET%20plastic%20is%201.38%20g%2Fcm%C2%B3%20and,(1.2%20g%2Fcm3).
t_vessel = 0.5e-3 # Thickness [m]
#c_vessel = 890 #J/kg aluminium
c_vessel = 1030 #J/kg Pet Source: https://www.engineeringtoolbox.com/specific-heat-polymers-d_1862.html

#Assumptions
A_factor=0.5 #Assume half of the area of the vessel is exposed to sunlight 
e = 0.9 # emissvity factor black epoxy
alpha=100#[W/M^2K] Convection heat transfer coeficient
P_crit=1e3 #[pa] critical pressure where the hysterical valve opens
cloud_factor = np.linspace(0.1,1,2) # 1 = sunny, 0 = dark

# %% [markdown]
# Simulation constants

# %%
#Vessel properties 
D = np.linspace(0.05,0.3,2) #Diameter vessel
L = np.linspace(0.05,0.3,2) #Lenght vessel

# Create a 2-D grid for D and L
D, L = np.meshgrid(D, L)

# Now D and L are 2-D arrays containing all combinations of diameter and length
V = D**2/4*np.pi*L  # [m^3]
A = D*L + D**2/4*np.pi  # [m^2]

#Air 
rho_air=1.293 #kgm-3 
m_air = rho_air*V #[kg]
R = constants.R #J/K*molz ideal gas constant 
c_air = 718 #j/kg K constant volume
n_mass = 28.96747 #molar mass [g/mol]
n = m_air/n_mass #Amount of mol air 
sigma = constants.sigma #Boltzman constant 

cp = 1000 #J/kgK @ 300 K
cv = 718 #J/kgK @ 300k
y = cp/cv 
K = 273.15 #Kelvin 

#Combined properties
m_vessel = A*t_vessel*rho_vessel
m = m_vessel+m_air #kg
c = m_vessel/m*c_vessel+m_air/m*c_air #j/kg K 

# Find the dimensions of A_exposed
num_rows, num_cols = A.shape
A_exposed= A_factor*A

# Create an array for each hour in the day, converted to seconds
dt=1 # Second
day_length = n_days*24 * 60 * 60  # length of a day in seconds
time_steps = np.linspace(0, day_length, num=day_length // dt + n_days)  # time steps
hours = np.arange(n_days*24)*60*60

# %% [markdown]
# Heat transfer coefficient alpha as function of windspeed and cilinder diameter

# %%
#Constants for heat transfer coefficient 
knu = 15.89e-6 #[m^2/s]
k_air = 26.3e-3 #W/(m*K)
Pr = 0.707 #dimensionless 
C = 0.26 #Constants from book
m_air_alpha = 0.6

# Define a function to compute heat transfer coefficient
def compute_alpha_hour(num_rows, num_cols, D, v_wind, time_steps, hours):
    #See example 7.4 solution analysis 2 of Dunfamentals of heat and mass transfer 
    alpha_hour = np.zeros((num_rows, num_cols, len(time_steps)))

    for ii in range(num_rows):
        for jj in range(num_cols):
            h = []
            
            #Calculate reynolds number and determine constants for nusselts 
            Re = v_wind*3.6*D[ii,jj]/knu            

            #Calculate nusselts
            #C and m_air_alpha are from table 7.4 of the aformentoined book. 
            # Pr is from table A4. 
            Nu = C*Re**m_air_alpha*Pr**(1/3)

            for aa in range(len(v_wind)): 
                #Calculate heat transfer coeeficient per timestep               
                h.append(Nu[aa]*k_air/D[ii,jj])  
                
            
            alpha_hour[ii, jj, :] = h #np.interp(time_steps, hours, h[:len(hours)])
    return alpha_hour

alpha_hour = compute_alpha_hour(num_rows, num_cols, D, df['v_wind'], time_steps, hours)

# %% [markdown]
# Define system of ODE's

# %%
# Define your system
def system(t, y, params):
    T, P, n_mol = y
    P_open,P_close,P_amb, solar_constants,R_valve, A_Exposed, cloud_factor, T_amb,R, m, c, ii, jj, ff = params

    # Interpolate the solar_constants and T_amb
    solar_constants_func = interp1d(np.arange(len(solar_constants)), solar_constants, bounds_error=False, fill_value="extrapolate")
    interpolated_solar_constants = solar_constants_func(t)
    P_sun = interpolated_solar_constants * A_Exposed[ii, jj] * cloud_factor[ff] *dt

    P_amb_func = interp1d(np.arange(len(P_amb)), P_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_P_amb = P_amb_func(t)

    #Interpolate T_amb and calculate heat loss through radiation, Q_rad
    T_amb_func = interp1d(np.arange(len(T_amb)), T_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_T_amb = T_amb_func(t)
    Q_rad = e * sigma * A_exposed[ii,jj] * (T**4 - interpolated_T_amb**4)
    
    alpha_interpolated_func = interp1d(np.arange(len(T_amb)), alpha_hour[ii,jj,:], bounds_error=False, fill_value="extrapolate")
    interpolated_alpha = alpha_interpolated_func(t)
    Q_con = interpolated_alpha * A_exposed[ii,jj] * (T - interpolated_T_amb)

 
    #Valve is normally closed
    dT_dt = (P_sun-Q_rad-Q_con) / (m[ii, jj] * c[ii, jj])
    dP_dt = (n_mol*R*dT_dt)/V[ii,jj]
    dn_dt = 0

    #Inlet opens when P_open is reached, compared to ambient pressure
    if (P <= (interpolated_P_amb-P_in)) and state[-1]==0:
        Q_in=(interpolated_P_amb-P) / R_valve #if P < interpolated_P_amb else 0 
        dP_dt +=  Q_in / V[ii,jj] 
        dn_dt +=(V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
        print('inlet is open')
        state.append(0)

    #Valve opens if P_open abiven ambient temperaturew is reached
    elif (P >= (interpolated_P_amb+P_open)) and state[-1]==0:
        #Volume flow out of tank is pressure difference devided by the resistance of the valve 
        Q_tank = -(P - interpolated_P_amb) / R_valve #if P > interpolated_P_amb else 0 
        
        # Pressure drop is related to the volume out and the original volume 
        dP_dt += Q_tank / V[ii,jj]  # Change in pressure in tank
        dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
        print('valve open, t=', t)
        state.append(1)

    #Valve stays open due to hysterisis
    elif ((interpolated_P_amb + P_close) <= P and P <= abs(interpolated_P_amb+P_open)) and state[-1]==1:
        Q_tank = (P - interpolated_P_amb) / R_valve #if P > interpolated_P_amb else 0 

        # Pressure drop is related to the volume out and the original volume 
        dP_dt -= Q_tank / V[ii,jj]  # Change in pressure in tank
        dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
        print('valve stayed open')
        state.append(1)
            
    #Valve closes if P_close is reached 
    elif P <=interpolated_P_amb + P_close and state[-1]==1:
        print('Valve closes')
        state.append(0)
    else:
        state.append(0)     

    
    return [dT_dt, dP_dt,dn_dt]



#Define simulation settings
t_span = [0, len(df['P_sun'].values)]  # start and end time

# Prepare params
P_open = 2e3 #pa 
P_close = 1e3 #pa
P_in = 0.3e3 #pa
R_valve=5000#1/12 # Resistance of first valve, Pa.s/m^3
valve_open_init = 0
params_base = [P_open,P_close,df['P_amb'].values,df['P_sun'].values, R_valve,A_exposed, cloud_factor,df['T_amb'].values, R,m, c]

# Use itertools.product to simplify nested loops

for ii, jj, ff in itertools.product(range(len(D)), range(len(L)), range(len(cloud_factor))):
    #ii=jj=1
    params = params_base + [ii, jj, ff]
    print(ii,jj,ff)
    
    # Define initial conditions
    n0 = df['P_amb'][0]*V[ii,jj]/(R*df['T_amb'][0])
    y0 = [df['T_amb'][0], df['P_amb'][0], n0]
    
    t_start= t_span[0]
    nsampling = int(100*len(df['P_amb'].values))
    solutions = []
    state=[]
    state.append(0)
        
    print(y0,t_start)
    sol = solve_ivp(system, [t_start, t_span[1]], y0, dense_output=True, args=(params,),method='RK45',
            t_eval=np.linspace(t_start,t_span[1],nsampling), rtol=1e-6, atol=1e-8)
      
    t= sol.t
    y= sol.y   
      
    break

 

# Concatenate the solutions
#t = np.concatenate([sol.t for sol in solutions])
#y = np.concatenate([sol.y for sol in solutions], axis=1)
# Out:
# 0 0 0
# [292.2, 101790.0, 0.004113302145481862] 0
# valve open, t= 30881.504819590653
# valve open, t= 30888.83942257619
# valve stayed open
# inlet is open
# valve open, t= 30833.389824005517
# inlet is open
# inlet is open
# valve open, t= 31148.252718568114
# inlet is open
# valve open, t= 31174.445127733285
# valve stayed open
# inlet is open
# valve open, t= 31064.43700923957
# inlet is open
# valve open, t= 31069.675491072605
# valve stayed open
# inlet is open
# valve open, t= 31047.673867373862
# inlet is open
# inlet is open
# valve open, t= 31119.90929904568
# inlet is open
# valve open, t= 31135.87276423042
# valve stayed open
# inlet is open
# valve open, t= 31068.826210454517
# inlet is open
# valve open, t= 31072.018903491466
# valve stayed open
# inlet is open
# valve open, t= 31058.609592736288
# valve open, t= 31059.248131343677
# inlet is open
# valve open, t= 31114.800990186508
# inlet is open
# valve open, t= 31127.571762334286
# valve stayed open
# inlet is open
# valve open, t= 31073.934519313618
# inlet is open
# inlet is open
# valve open, t= 31109.94620548074
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 31146.295923852325
# valve stayed open
# inlet is open
# valve open, t= 31102.676261806424
# inlet is open
# inlet is open
# valve open, t= 31115.139022390984
# inlet is open
# valve open, t= 31119.293275919168
# valve stayed open
# inlet is open
# valve open, t= 31101.845411100796
# valve open, t= 31102.67626180643
# inlet is open
# valve open, t= 31106.8305153346
# inlet is open
# inlet is open
# valve open, t= 31106.8305153346
# inlet is open
# valve open, t= 31116.800723802226
# inlet is open
# valve open, t= 31120.124126624767
# valve stayed open
# inlet is open
# valve open, t= 31106.165834770094
# valve open, t= 31106.8305153346
# inlet is open
# valve open, t= 31106.165834770087
# inlet is open
# valve open, t= 31110.153918157128
# inlet is open
# inlet is open
# valve open, t= 31105.899962544285
# inlet is open
# valve open, t= 31105.909900824467
# inlet is open
# valve open, t= 31107.520041599557
# valve open, t= 31108.056755191254
# inlet is open
# valve open, t= 31105.802558106127
# valve open, t= 31105.655515912164
# valve stayed open
# valve stayed open
# valve stayed open
# valve open, t= 31105.564221879027
# valve open, t= 31105.720314205148
# valve open, t= 31105.67364004192
# valve open, t= 31105.64217099239
# valve open, t= 31105.64389380572
# valve open, t= 31105.6422267341
# valve stayed open
# valve open, t= 31105.647071903564
# valve open, t= 31105.64162916455
# valve stayed open
# valve open, t= 31105.64441603891
# valve open, t= 31105.641340917682
# valve stayed open
# valve open, t= 31105.643134941714
# valve open, t= 31105.641186588076
# valve stayed open
# valve open, t= 31105.64244903235
# valve open, t= 31105.641096907708
# valve stayed open
# valve open, t= 31105.64205045293
# valve open, t= 31105.641041307175
# valve stayed open
# valve open, t= 31105.64180333945
# valve open, t= 31105.641005015743
# valve stayed open
# valve open, t= 31105.641642044204
# valve open, t= 31105.640980337517
# valve stayed open
# valve open, t= 31105.641532363195
# valve open, t= 31105.640962999514
# valve stayed open
# valve open, t= 31105.64145530541
# valve open, t= 31107.67029780212
# inlet is open
# valve open, t= 31111.583052078946
# inlet is open
# inlet is open
# valve open, t= 31107.409447517
# inlet is open
# valve open, t= 31107.426395985924
# inlet is open
# valve open, t= 31109.01692040004
# valve open, t= 31109.547095204747
# inlet is open
# valve open, t= 31107.426395985924
# valve stayed open
# valve stayed open
# valve stayed open
# valve open, t= 31107.036117919994
# valve open, t= 31107.05360501234
# valve stayed open
# valve stayed open
# valve open, t= 31106.93329402334
# valve open, t= 31107.421365327158
# Valve closes
# valve open, t= 31108.406010600796
# valve open, t= 31108.73422569201
# inlet is open
# valve open, t= 31107.38489698369
# valve open, t= 31107.421365327158
# valve stayed open
# valve stayed open
# valve open, t= 31107.165539021415
# valve open, t= 31107.174587619596
# valve stayed open
# valve stayed open
# valve open, t= 31107.11599369891
# valve open, t= 31107.453595671454
# Valve closes
# valve open, t= 31108.12943086303
# valve open, t= 31108.354709260224
# inlet is open
# valve open, t= 31107.408539992015
# valve open, t= 31107.510264534925
# valve stayed open
# valve open, t= 31107.995840372736
# valve open, t= 31108.074159056254
# valve open, t= 31107.411582993693
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 31107.38624900626
# valve stayed open
# Valve closes
# valve open, t= 31107.390937261902
# valve open, t= 31107.382225960522
# valve stayed open
# valve stayed open
# valve stayed open
# valve open, t= 31107.37673380389
# valve open, t= 31107.387878677386
# valve stayed open
# valve open, t= 31107.41989095275
# valve open, t= 31107.382151614343
# valve stayed open
# valve open, t= 31107.394437339226
# valve open, t= 31107.38534833884
# valve open, t= 31107.382665072677
# valve open, t= 31107.381610729677
# valve open, t= 31107.381988972014
# valve stayed open
# valve stayed open
# valve open, t= 31107.38048112225
# valve open, t= 31107.38153678242
# valve open, t= 31107.381710428977
# valve stayed open
# valve stayed open
# valve open, t= 31107.381164944345
# valve open, t= 31107.381858038243
# valve open, t= 31133.586872224885
# inlet is open
# valve open, t= 31182.61626000065
# inlet is open
# valve open, t= 31198.95938925924
# valve open, t= 31122.146681743874
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 31133.586872224885
# valve stayed open
# inlet is open
# valve open, t= 31119.85864364767
# valve open, t= 31120.512368818014
# inlet is open
# valve open, t= 31119.858643647676
# inlet is open
# valve open, t= 31123.780994669745
# inlet is open
# inlet is open
# valve open, t= 31120.120133715813
# Valve closes
# valve open, t= 31120.90460392023
# valve open, t= 31121.166093988366
# inlet is open
# valve open, t= 31119.910941661303
# valve stayed open
# valve open, t= 31120.0910792638
# valve open, t= 31120.120133715813
# valve open, t= 31119.87631663507
# valve stayed open
# inlet is open
# valve open, t= 31119.86385594862
# valve stayed open
# valve open, t= 31119.881809429648
# valve open, t= 31119.8620600482
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 33461.86341964961
# valve stayed open
# inlet is open
# valve open, t= 33242.32956771286
# inlet is open
# valve open, t= 33252.78356066223
# valve stayed open
# inlet is open
# valve open, t= 33208.87679027488
# inlet is open
# inlet is open
# valve open, t= 33407.6858664772
# inlet is open
# valve open, t= 33437.38505398043
# valve stayed open
# inlet is open
# valve open, t= 33366.033790564536
# inlet is open
# valve open, t= 33369.43146977482
# valve stayed open
# inlet is open
# valve open, t= 33355.16121709164
# valve open, t= 33355.8407529337
# inlet is open
# valve open, t= 33434.41846614628
# valve open, t= 33442.34492710488
# valve stayed open
# inlet is open
# valve open, t= 33382.42088225786
# inlet is open
# valve open, t= 33385.27440820295
# valve stayed open
# inlet is open
# valve open, t= 33373.28959923355
# valve open, t= 33373.86030442257
# inlet is open
# valve open, t= 33434.925759647755
# inlet is open
# valve open, t= 33466.823951184844
# inlet is open
# valve open, t= 33483.359076904424
# valve stayed open
# inlet is open
# valve open, t= 33413.9115488822
# inlet is open
# valve open, t= 33417.21857402611
# valve stayed open
# inlet is open
# valve open, t= 33403.32906842166
# valve open, t= 33403.990473450445
# inlet is open
# valve open, t= 33474.760811530185
# valve stayed open
# inlet is open
# valve open, t= 33419.202789112445
# inlet is open
# inlet is open
# valve open, t= 33435.07650980323
# inlet is open
# valve open, t= 33440.36775003349
# valve stayed open
# inlet is open
# valve open, t= 33418.144541066395
# inlet is open
# inlet is open
# valve open, t= 33446.7494497923
# inlet is open
# valve open, t= 33451.78418088168
# valve stayed open
# inlet is open
# valve open, t= 33430.6383103063
# inlet is open
# inlet is open
# valve open, t= 33437.5750509183
# valve open, t= 33438.693880049264
# valve stayed open
# Valve closes
# valve open, t= 33430.23553181913
# valve open, t= 33430.63831030628
# inlet is open
# valve open, t= 33441.513329459354
# inlet is open
# valve open, t= 33465.680038688384
# inlet is open
# valve open, t= 33473.735608431394
# valve stayed open
# inlet is open
# valve open, t= 33439.90221551075
# inlet is open
# inlet is open
# valve open, t= 33439.90221551075
# inlet is open
# valve open, t= 33449.568899202364
# inlet is open
# valve open, t= 33452.79112709957
# valve open, t= 33437.64665598271
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 33439.90221551075
# valve stayed open
# valve stayed open
# valve open, t= 33437.25282812861
# valve open, t= 33437.32443319299
# valve stayed open
# valve stayed open
# valve open, t= 33436.794555716566
# valve open, t= 33436.80887672944
# valve stayed open
# valve stayed open
# valve open, t= 33436.712110425644
# valve open, t= 33437.150081132044
# Valve closes
# valve open, t= 33438.03150647922
# valve open, t= 33438.32531492828
# inlet is open
# valve open, t= 33437.09131944223
# valve open, t= 33436.960886235436
# valve stayed open
# valve open, t= 33437.0209421637
# valve open, t= 33437.03062860374
# valve stayed open
# valve stayed open
# valve open, t= 33436.96749957419
# valve open, t= 33436.96455865257
# valve open, t= 33436.96106770313
# valve open, t= 33436.96180400163
# valve stayed open
# valve stayed open
# valve open, t= 33436.95840810107
# valve open, t= 33436.96474211237
# valve stayed open
# valve open, t= 33436.98121481869
# valve open, t= 33436.96208899467
# valve stayed open
# valve open, t= 33436.96942318447
# valve open, t= 33436.961084335264
# valve stayed open
# valve open, t= 33436.964958031574
# valve open, t= 33436.9609754368
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 33838.73991443443
# inlet is open
# valve open, t= 33896.89761362601
# inlet is open
# valve open, t= 33948.65805845111
# valve open, t= 33956.80912849642
# valve stayed open
# inlet is open
# valve open, t= 33895.18703895392
# inlet is open
# valve open, t= 33898.121424170226
# valve stayed open
# inlet is open
# valve open, t= 33885.79700626172
# valve open, t= 33886.38388330498
# inlet is open
# valve open, t= 34209.30052360442
# valve stayed open
# inlet is open
# valve open, t= 34142.30609426933
# inlet is open
# valve open, t= 34145.49630519005
# valve stayed open
# inlet is open
# valve open, t= 34132.09741932303
# valve open, t= 34132.735461507174
# inlet is open
# valve open, t= 34201.00597521079
# valve stayed open
# inlet is open
# valve open, t= 34147.41043174254
# inlet is open
# inlet is open
# valve open, t= 34210.181875353774
# inlet is open
# valve open, t= 34224.40230162114
# valve stayed open
# inlet is open
# valve open, t= 34164.67651129819
# inlet is open
# valve open, t= 34167.520596551665
# valve stayed open
# inlet is open
# valve open, t= 34155.575438487074
# valve open, t= 34156.14425553777
# inlet is open
# valve open, t= 34205.63133894854
# inlet is open
# valve open, t= 34217.0076799625
# valve stayed open
# inlet is open
# valve open, t= 34169.22704770385
# inlet is open
# inlet is open
# valve open, t= 34210.83914857317
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 34265.462377482785
# valve stayed open
# inlet is open
# valve open, t= 34199.914502791245
# inlet is open
# valve open, t= 34203.03583015751
# valve stayed open
# inlet is open
# valve open, t= 34189.9262552192
# valve open, t= 34190.55052069246
# inlet is open
# valve open, t= 34207.40568847038
# inlet is open
# valve open, t= 34244.86161686574
# inlet is open
# valve open, t= 34257.34692633086
# valve stayed open
# inlet is open
# valve open, t= 34204.90862657736
# inlet is open
# inlet is open
# valve open, t= 34205.9261351968
# inlet is open
# inlet is open
# valve open, t= 34202.61973737378
# inlet is open
# valve open, t= 34202.61973737377
# inlet is open
# valve open, t= 34204.423227095394
# valve open, t= 34205.02439033594
# inlet is open
# valve open, t= 34202.49950472566
# valve open, t= 34202.63689483542
# Valve closes
# valve open, t= 34203.564375888716
# valve open, t= 34203.873536239815
# inlet is open
# valve open, t= 34202.5750627652
# valve open, t= 34202.49118210815
# valve open, t= 34202.448828242486
# valve open, t= 34202.45261443283
# valve stayed open
# valve stayed open
# valve open, t= 34202.430499120856
# valve open, t= 34202.4523830672
# valve stayed open
# inlet is open
# inlet is open
# valve open, t= 34202.456283588464
# valve open, t= 34202.44905202889
# valve stayed open
# valve open, t= 34202.4587972636
# valve open, t= 34202.45185654006
# valve open, t= 34202.449748245075
# valve open, t= 34202.448914986526
# valve open, t= 34202.44925151394
# valve stayed open
# valve stayed open
# valve open, t= 34202.44794999315
# valve open, t= 34202.44883379729
# valve open, t= 34202.44878006401
# valve open, t= 34202.44891840458
# valve stayed open
# valve stayed open
# valve open, t= 34202.44852158991
# valve open, t= 34202.44915256977
# valve open, t= 34211.229919849975
# inlet is open
# valve open, t= 34211.229919849975
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 34222.2935901675
# valve stayed open
# inlet is open
# valve open, t= 34209.01718578647
# valve open, t= 34209.6493955189
# inlet is open
# valve open, t= 34212.81044418105
# inlet is open
# inlet is open
# valve open, t= 34214.0175292741
# inlet is open
# valve open, t= 34223.41467370283
# inlet is open
# valve open, t= 34226.54705517907
# valve open, t= 34211.824862240726
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 34214.0175292741
# valve open, t= 34211.07309068643
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 34211.004901181805
# valve open, t= 34210.976641466994
# valve open, t= 34210.95501919129
# valve open, t= 34210.95739938845
# valve stayed open
# valve stayed open
# valve open, t= 34210.944232245885
# valve open, t= 34210.956159172194
# valve stayed open
# valve open, t= 34210.99091630012
# valve open, t= 34210.961264898906
# valve open, t= 34210.95473264876
# valve open, t= 34210.95581568072
# valve stayed open
# valve stayed open
# valve open, t= 34210.95046711964
# valve open, t= 34210.95830090963
# valve stayed open
# valve open, t= 34210.979368021406
# valve open, t= 34210.95476526378
# valve stayed open
# valve open, t= 34210.96365403983
# valve open, t= 34210.957423108244
# valve open, t= 34210.955510798965
# valve open, t= 34210.95449741928
# valve open, t= 34210.95434634681
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 37714.335530648714
# valve open, t= 37730.5394558395
# valve stayed open
# inlet is open
# valve open, t= 37608.03778139719
# inlet is open
# valve open, t= 37613.87119446587
# valve stayed open
# inlet is open
# valve open, t= 37589.37085957741
# inlet is open
# inlet is open
# valve open, t= 38350.22150252974
# valve stayed open
# inlet is open
# valve open, t= 38282.980401769004
# inlet is open
# valve open, t= 38286.182358948085
# valve stayed open
# inlet is open
# valve open, t= 38272.73413879593
# valve open, t= 38273.37453023175
# inlet is open
# valve open, t= 38341.89641386407
# valve stayed open
# inlet is open
# valve open, t= 38288.10353325552
# inlet is open
# inlet is open
# valve open, t= 38303.472927715105
# inlet is open
# valve open, t= 38308.596059201634
# valve stayed open
# inlet is open
# valve open, t= 38287.07890695821
# inlet is open
# inlet is open
# valve open, t= 38309.95635012323
# inlet is open
# valve open, t= 38353.99764848286
# inlet is open
# valve open, t= 38368.6780812694
# valve stayed open
# inlet is open
# valve open, t= 38307.02026356592
# inlet is open
# valve open, t= 38309.95635012323
# valve stayed open
# inlet is open
# valve open, t= 38297.62478658254
# valve open, t= 38298.212003894005
# inlet is open
# valve open, t= 38301.148090451316
# inlet is open
# inlet is open
# valve open, t= 38301.148090451316
# inlet is open
# valve open, t= 38308.19469818886
# inlet is open
# inlet is open
# valve open, t= 38299.503881979224
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 38301.148090451316
# valve stayed open
# valve stayed open
# valve open, t= 38299.21679796028
# valve open, t= 38299.268995054634
# valve stayed open
# valve stayed open
# valve open, t= 38298.882736556436
# valve open, t= 38298.8931759753
# valve stayed open
# valve stayed open
# valve open, t= 38298.82466181124
# valve open, t= 38299.92661665383
# inlet is open
# valve open, t= 38299.40469480019
# valve open, t= 38299.51201014235
# valve stayed open
# valve open, t= 38300.04772193408
# valve open, t= 38300.134127061785
# valve stayed open
# valve stayed open
# valve open, t= 38299.494729116814
# valve open, t= 38299.51201014235
# valve stayed open
# valve stayed open
# valve open, t= 38299.393247729655
# valve open, t= 38299.42171336232
# valve stayed open
# valve open, t= 38299.53405813701
# valve open, t= 38299.55217826196
# valve open, t= 38299.40192922256
# valve stayed open
# Valve closes
# valve open, t= 38299.393265808045
# valve stayed open
# valve open, t= 38299.407624562475
# valve open, t= 38299.39100899056
# valve stayed open
# valve open, t= 38299.397594262555
# valve open, t= 38299.39064603519
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 38555.20851585615
# inlet is open
# valve open, t= 39081.85383301772
# valve open, t= 39096.690211748704
# valve stayed open
# inlet is open
# valve open, t= 38984.52718854243
# inlet is open
# valve open, t= 38989.86828488558
# valve stayed open
# inlet is open
# valve open, t= 38967.43568024433
# inlet is open
# inlet is open
# valve open, t= 39855.889786986474
# inlet is open
# valve open, t= 39961.942122677196
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 40049.68037728705
# valve stayed open
# inlet is open
# valve open, t= 39944.39447175523
# inlet is open
# valve open, t= 39949.408086304364
# valve stayed open
# inlet is open
# valve open, t= 39928.350905198
# inlet is open
# inlet is open
# valve open, t= 39952.993915714214
# inlet is open
# valve open, t= 40002.85759742702
# inlet is open
# valve open, t= 40019.47882466462
# valve stayed open
# inlet is open
# valve open, t= 39949.669670266696
# inlet is open
# valve open, t= 39952.993915714214
# valve stayed open
# inlet is open
# valve open, t= 39939.03208483463
# valve open, t= 39939.69693392413
# inlet is open
# valve open, t= 39957.64785934069
# inlet is open
# valve open, t= 39997.53880471082
# inlet is open
# valve open, t= 40010.835786500866
# valve stayed open
# inlet is open
# valve open, t= 39954.98846298268
# inlet is open
# valve open, t= 39957.64785934069
# valve stayed open
# inlet is open
# valve open, t= 39946.47839463705
# valve open, t= 39947.01027390865
# inlet is open
# valve open, t= 39961.371014241806
# inlet is open
# valve open, t= 39993.28377053774
# inlet is open
# valve open, t= 40003.92135596972
# valve open, t= 39953.92470443942
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 39961.371014241806
# valve stayed open
# Valve closes
# valve open, t= 39952.43544247894
# valve open, t= 39952.860945896224
# inlet is open
# valve open, t= 39952.435442478956
# inlet is open
# valve open, t= 39954.98846298265
# valve open, t= 39955.83946981721
# inlet is open
# valve open, t= 39951.754637011305
# valve stayed open
# valve open, t= 39952.340886164005
# valve open, t= 39952.435442478956
# valve open, t= 39951.63549605446
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 39951.5980243558
# valve stayed open
# valve open, t= 39951.64482991731
# valve open, t= 39951.589197660185
# valve stayed open
# valve open, t= 39951.60560015904
# valve open, t= 39951.58655800624
# valve stayed open
# valve open, t= 39951.59386836369
# valve open, t= 39951.585557471255
# valve stayed open
# valve open, t= 39951.58942154157
# valve open, t= 39951.58511151544
# valve stayed open
# valve open, t= 39951.58743951571
# valve open, t= 39951.58488693678
# valve stayed open
# valve open, t= 39951.58644138833
# valve open, t= 39951.584926041454
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 43497.98861320868
# inlet is open
# valve open, t= 43551.458096227034
# valve open, t= 43560.42909239496
# valve stayed open
# inlet is open
# valve open, t= 43492.608361365455
# inlet is open
# valve open, t= 43495.837919985905
# valve stayed open
# inlet is open
# valve open, t= 43482.273773780005
# valve open, t= 43482.919685504094
# inlet is open
# valve open, t= 43694.51023509528
# inlet is open
# valve open, t= 43816.98145569178
# valve stayed open
# inlet is open
# valve open, t= 43743.89084029365
# inlet is open
# valve open, t= 43747.3713457888
# valve stayed open
# inlet is open
# valve open, t= 43732.75322270918
# valve open, t= 43733.44932380821
# inlet is open
# valve open, t= 43807.9321414041
# valve stayed open
# inlet is open
# valve open, t= 43749.45964908582
# inlet is open
# valve open, t= 43752.244053481925
# valve stayed open
# inlet is open
# valve open, t= 43740.54955501827
# valve open, t= 43741.10643589749
# inlet is open
# valve open, t= 43822.2103755469
# inlet is open
# valve open, t= 43837.90043189005
# valve stayed open
# inlet is open
# valve open, t= 43772.00219524884
# inlet is open
# valve open, t= 43775.14020651747
# valve stayed open
# inlet is open
# valve open, t= 43761.960559189225
# valve open, t= 43762.58816144295
# inlet is open
# valve open, t= 43817.18955751727
# inlet is open
# valve open, t= 43829.74160259182
# valve stayed open
# inlet is open
# valve open, t= 43777.0230132787
# inlet is open
# inlet is open
# valve open, t= 43792.08546736816
# inlet is open
# valve open, t= 43797.10628539798
# valve stayed open
# inlet is open
# valve open, t= 43776.018849672735
# inlet is open
# inlet is open
# valve open, t= 43802.71492384264
# inlet is open
# valve open, t= 43858.70321980935
# inlet is open
# valve open, t= 43877.36598513158
# valve stayed open
# inlet is open
# valve open, t= 43798.9823707782
# inlet is open
# valve open, t= 43802.71492384264
# valve stayed open
# inlet is open
# valve open, t= 43787.03820097197
# valve open, t= 43787.784711584856
# inlet is open
# valve open, t= 43791.51726464929
# inlet is open
# inlet is open
# valve open, t= 43788.232617952584
# inlet is open
# valve open, t= 43788.23261795257
# inlet is open
# valve open, t= 43790.02424342348
# valve open, t= 43790.62145191379
# inlet is open
# valve open, t= 43788.11317625451
# valve open, t= 43787.91221261952
# valve open, t= 43787.99695661246
# valve stayed open
# valve open, t= 43788.35477862189
# valve open, t= 43788.41249184922
# valve open, t= 43787.92423794602
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 43787.902759899094
# valve stayed open
# valve open, t= 43787.9361265625
# valve open, t= 43787.89675535972
# valve stayed open
# valve open, t= 43787.90943972085
# valve open, t= 43787.89567413765
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 46097.68471719706
# inlet is open
# valve open, t= 46411.32714151652
# valve stayed open
# inlet is open
# valve open, t= 46333.2576066408
# inlet is open
# valve open, t= 46336.975203539645
# valve stayed open
# inlet is open
# valve open, t= 46321.3612965645
# valve open, t= 46322.10481594427
# inlet is open
# valve open, t= 46441.14545719998
# inlet is open
# valve open, t= 46457.485199572984
# valve stayed open
# inlet is open
# valve open, t= 46388.85828160634
# inlet is open
# valve open, t= 46392.12623008095
# valve stayed open
# inlet is open
# valve open, t= 46378.400846487624
# valve open, t= 46379.054436182545
# inlet is open
# valve open, t= 46419.66474553527
# inlet is open
# valve open, t= 46471.32362137111
# inlet is open
# valve open, t= 46488.54324664973
# valve open, t= 46407.61100784024
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 46419.66474553527
# valve stayed open
# inlet is open
# valve open, t= 46405.20026030124
# valve open, t= 46405.88904531238
# inlet is open
# valve open, t= 46405.88904531238
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 46410.7105403904
# valve stayed open
# Valve closes
# valve open, t= 46404.924746296776
# valve open, t= 46405.20026030124
# inlet is open
# valve open, t= 46406.57783032356
# inlet is open
# inlet is open
# valve open, t= 46405.36556870393
# valve open, t= 46405.501509101116
# Valve closes
# valve open, t= 46406.3666533076
# valve open, t= 46406.655034709765
# inlet is open
# valve open, t= 46405.44383282068
# valve open, t= 46405.324792170104
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 46405.334935893356
# valve open, t= 46405.32229920319
# valve stayed open
# valve open, t= 46405.335661211946
# valve open, t= 46405.32022665505
# valve stayed open
# valve open, t= 46405.3264498869
# valve open, t= 46405.31940721021
# valve stayed open
# valve open, t= 46405.32280790985
# valve open, t= 46405.31903040054
# valve stayed open
# valve open, t= 46405.321133200196
# valve open, t= 46405.31883601816
# valve stayed open
# valve open, t= 46405.32026927848
# valve open, t= 46405.31872632341
# valve stayed open
# valve open, t= 46405.31978174627
# valve open, t= 46405.318659874305
# valve stayed open
# valve open, t= 46405.319486416905
# valve open, t= 46405.31861729456
# valve stayed open
# valve open, t= 46405.319297173584
# valve open, t= 46405.31858876251
# valve stayed open
# valve open, t= 46405.31917036448
# valve open, t= 46405.31856895037
# valve stayed open
# valve open, t= 46405.319082310554
# valve open, t= 46408.091756938986
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 46412.81278413403
# valve stayed open
# Valve closes
# valve open, t= 46407.14755149998
# valve open, t= 46407.41732448255
# inlet is open
# valve open, t= 46408.76618939542
# inlet is open
# inlet is open
# valve open, t= 46408.76618939542
# inlet is open
# valve open, t= 46412.00346518631
# inlet is open
# inlet is open
# valve open, t= 46408.01082504421
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 46408.07557056003
# valve open, t= 46407.98465874882
# valve stayed open
# valve open, t= 46408.031585227094
# valve open, t= 46407.97580621775
# valve stayed open
# valve open, t= 46407.99224064456
# valve open, t= 46407.97422334437
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# valve open, t= 52988.84150614534
# valve stayed open
# inlet is open
# valve open, t= 52905.878753052464
# inlet is open
# valve open, t= 52909.8293603426
# valve stayed open
# inlet is open
# valve open, t= 52893.23680972402
# valve open, t= 52894.026931182045
# inlet is open
# valve open, t= 52978.56992719093
# valve stayed open
# inlet is open
# valve open, t= 52912.199724716666
# inlet is open
# valve open, t= 52915.36021054877
# valve stayed open
# inlet is open
# valve open, t= 52902.08617005392
# valve open, t= 52902.71826722034
# inlet is open
# valve open, t= 52957.71072069929
# inlet is open
# valve open, t= 52970.35266402778
# valve stayed open
# inlet is open
# valve open, t= 52917.25650204812
# inlet is open
# inlet is open
# valve open, t= 52978.80342256429
# valve stayed open
# inlet is open
# valve open, t= 52944.094781164196
# inlet is open
# inlet is open
# valve open, t= 52977.083936745556
# inlet is open
# valve open, t= 53036.38438474661
# inlet is open
# valve open, t= 53056.151200746965
# valve stayed open
# inlet is open
# valve open, t= 52973.13057354549
# inlet is open
# valve open, t= 52977.083936745556
# valve stayed open
# inlet is open
# valve open, t= 52960.47981130526
# valve open, t= 52961.27048394527
# inlet is open
# valve open, t= 52982.61864522554
# inlet is open
# valve open, t= 53030.05900362618
# inlet is open
# valve open, t= 53045.87245642639
# valve stayed open
# inlet is open
# valve open, t= 52979.4559546655
# inlet is open
# valve open, t= 52982.61864522554
# valve stayed open
# inlet is open
# valve open, t= 52969.33534487336
# valve open, t= 52969.96788298537
# inlet is open
# valve open, t= 52987.046412009695
# inlet is open
# valve open, t= 53024.99869873038
# inlet is open
# valve open, t= 53037.649460970606
# valve open, t= 52978.190878441535
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 52987.046412009695
# valve open, t= 52975.15469550388
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 52976.92580221751
# valve stayed open
# valve stayed open
# valve open, t= 52974.84545464912
# valve open, t= 52974.90168025908
# valve stayed open
# valve stayed open
# valve open, t= 52974.485610745396
# valve open, t= 52974.496855867386
# valve stayed open
# valve stayed open
# valve open, t= 52974.42254297841
# valve open, t= 52974.80516448839
# Valve closes
# valve open, t= 52975.57300458637
# valve open, t= 52975.82895128569
# inlet is open
# valve open, t= 52974.753975148524
# valve open, t= 52974.68976101433
# valve open, t= 52974.681662482144
# valve open, t= 52974.66880196952
# valve open, t= 52974.667500351556
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# valve stayed open
# Valve closes
# inlet is open
# valve open, t= 67859.49261697402
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68169.58425678265
# Valve closes
# inlet is open
# valve open, t= 68209.7754181799
# inlet is open
# valve open, t= 68225.11311356416
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68179.10002741136
# Valve closes
# inlet is open
# valve open, t= 68179.10002741139
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68200.5728009494
# Valve closes
# inlet is open
# valve open, t= 68174.80547270378
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68224.93238967608
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68281.0722079584
# Valve closes
# inlet is open
# valve open, t= 68213.70442601961
# inlet is open
# valve open, t= 68216.91241563574
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68207.28844678734
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68242.19647773661
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68274.06923440244
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68237.64322678433
# Valve closes
# inlet is open
# valve open, t= 68237.64322678435
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68250.3923294507
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68268.29678766974
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68326.35764840696
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68260.00237899298
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68252.51812028838
# Valve closes
# inlet is open
# valve open, t= 68246.14492923416
# valve open, t= 68246.44841452246
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68298.99347497142
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68359.38262083486
# Valve closes
# inlet is open
# valve open, t= 68286.91564579873
# inlet is open
# valve open, t= 68290.36645413378
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68299.79791985652
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68328.52685377511
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68295.69378643957
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68324.34430093487
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68381.31581320215
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68316.20551346813
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68310.10134094491
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68381.60802342933
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68454.74846385675
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68371.15938908256
# Valve closes
# inlet is open
# valve open, t= 68371.15938908253
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68400.41556525345
# Valve closes
# inlet is open
# valve open, t= 68365.30815384835
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68362.94207923552
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68405.89941694819
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68467.77281481976
# inlet is open
# valve open, t= 68384.68568053508
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68397.0603601094
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68382.91786916733
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68420.75598076113
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68489.48748958523
# Valve closes
# inlet is open
# valve open, t= 68407.00967899631
# inlet is open
# valve open, t= 68410.93719378626
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68399.1546494164
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68491.06506313896
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68480.60695205397
# Valve closes
# inlet is open
# valve open, t= 68498.1292535719
# inlet is open
# valve open, t= 68505.13817417905
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68484.11141235758
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68482.2856662332
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68522.7093515935
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68581.68079492022
# inlet is open
# valve open, t= 68502.49057102433
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68514.28485968968
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68500.80567264358
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68549.01804783334
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68540.72079218156
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68538.26764537476
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68574.10756586713
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68629.98244412833
# Valve closes
# inlet is open
# valve open, t= 68562.93259021488
# inlet is open
# valve open, t= 68566.12544040124
# Valve closes
# inlet is open
# valve open, t= 68555.90831980492
# valve open, t= 68556.5468898422
# inlet is open
# inlet is open
# valve open, t= 68554.56022750403
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68600.05871466776
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68662.6181066022
# inlet is open
# valve open, t= 68578.60978029024
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68591.12165867712
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68582.55063566477
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68589.82229645278
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68603.4054168116
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68594.24630301073
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68591.77820063979
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68633.29114460436
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68689.00963686459
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68625.33135999575
# Valve closes
# inlet is open
# valve open, t= 68611.9589218533
# valve open, t= 68612.59570462198
# inlet is open
# inlet is open
# valve open, t= 68610.61460267496
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68656.4953992937
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68719.31058546972
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68647.52180126855
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68644.16445265517
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68660.85250102726
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68683.9266556461
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68657.55619322456
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68666.78585507216
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68656.23767010351
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68688.91191988296
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68748.06251308715
# Valve closes
# inlet is open
# valve open, t= 68677.08180124212
# inlet is open
# valve open, t= 68680.4618351395
# Valve closes
# inlet is open
# valve open, t= 68669.64572666788
# valve open, t= 68670.32173344736
# inlet is open
# inlet is open
# valve open, t= 68668.21860124456
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68701.98676193014
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68760.25395625675
# Valve closes
# inlet is open
# valve open, t= 68690.33332306481
# inlet is open
# valve open, t= 68693.66287702633
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68744.82713222566
# Valve closes
# inlet is open
# valve open, t= 68809.76215337287
# inlet is open
# valve open, t= 68825.57980047136
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68778.12685917591
# Valve closes
# inlet is open
# valve open, t= 68778.12685917594
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68800.27156511387
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68774.96332975624
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68783.82121213134
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68875.40208176356
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68844.4983027954
# Valve closes
# inlet is open
# valve open, t= 68844.49830279539
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68858.92006631385
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68848.2067562716
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68878.64753560812
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68941.01533571917
# inlet is open
# valve open, t= 68857.26428985575
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68869.73784987796
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68862.85621043218
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68860.13720775735
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 68855.6610586706
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# ...
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78518.3979086286
# Valve closes
# inlet is open
# valve open, t= 78518.3979086286
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78534.28272991432
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78520.94163645414
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78564.06825010992
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78646.95325979766
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78552.22753444024
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78544.64947641165
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78539.43956072732
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78647.7786923682
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78836.68947399234
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78620.79143785046
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78588.40673242918
# Valve closes
# inlet is open
# valve open, t= 78588.40673242918
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78603.51959495911
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78594.68317813637
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78593.38005432133
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78622.21135420635
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78684.19362686484
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78613.35674382656
# Valve closes
# inlet is open
# valve open, t= 78613.35674382656
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78638.14965288996
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78609.81489967465
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78607.95833405349
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78669.14378438835
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78779.92109125355
# inlet is open
# valve open, t= 78631.16299346313
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78653.31845483618
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78634.32805937357
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78629.26395391687
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78730.98262682391
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78908.33005747767
# Valve closes
# inlet is open
# valve open, t= 78695.51314069316
# inlet is open
# valve open, t= 78705.64727958766
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78675.24486290416
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78674.99305239148
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78704.0055578404
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78764.24491094117
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78695.39993596886
# Valve closes
# inlet is open
# valve open, t= 78695.39993596886
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78719.49567720917
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78691.95768722025
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78690.18236797268
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78721.31331503182
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78780.7335717472
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78712.82470692962
# Valve closes
# inlet is open
# valve open, t= 78712.82470692962
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78736.59280961577
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78709.42926368874
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78707.69187576941
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78867.16937805469
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79106.9192884289
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78832.91939085838
# Valve closes
# inlet is open
# valve open, t= 78832.91939085837
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78928.81935500803
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 78819.21939597985
# Valve closes
# inlet is open
# valve open, t= 78846.61938573686
# inlet is open
# valve open, t= 78857.57938163968
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78824.69939393124
# Valve closes
# inlet is open
# valve open, t= 78815.49299737287
# valve open, t= 78815.93139720899
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78869.09649561258
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78962.50637839822
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78855.7522266432
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78849.51443534857
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78845.20459529772
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78841.5408919443
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78873.65792273536
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78932.12848246381
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78865.3049856313
# Valve closes
# inlet is open
# valve open, t= 78865.3049856313
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78888.69320952268
# Valve closes
# inlet is open
# valve open, t= 78860.62734085303
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78857.6871069924
# valve open, t= 78857.95440097972
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79004.29904181696
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79241.15616883757
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78970.46230938545
# Valve closes
# inlet is open
# valve open, t= 78970.46230938546
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79065.20516019371
# Valve closes
# inlet is open
# valve open, t= 78951.51373922381
# inlet is open
# valve open, t= 78956.92761641285
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 78941.539625798
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79090.00175693815
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79324.20330737495
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79056.54439259003
# Valve closes
# inlet is open
# valve open, t= 79056.54439259002
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79150.22501276471
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79043.16144685078
# Valve closes
# inlet is open
# valve open, t= 79043.16144685079
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79080.63369492069
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79037.80826855509
# Valve closes
# inlet is open
# valve open, t= 79037.80826855509
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79052.79716778305
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79044.05408652293
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79042.83783023438
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79350.60356817607
# inlet is open
# valve open, t= 79413.78622371305
# Valve closes
# inlet is open
# valve open, t= 79180.01039822624
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79224.23825710212
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79173.69213267253
# Valve closes
# inlet is open
# valve open, t= 79173.69213267256
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79191.38327622294
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79178.24128387126
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79175.08013578306
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79204.23066949446
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79262.51434236622
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 79212.55690847614
# inlet is open
# valve open, t= 79219.21789966148
# Valve closes
# inlet is open
# valve open, t= 79197.90272786838
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79257.26411128884
# inlet is open
# valve open, t= 79268.27445799683
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79235.24341787286
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79233.87469562223
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79292.02885017409
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79400.08800140319
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 79276.59182856993
# Valve closes
# inlet is open
# valve open, t= 79307.46587177824
# inlet is open
# valve open, t= 79319.81548906157
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79282.7666372116
# Valve closes
# inlet is open
# valve open, t= 79272.3929586936
# valve open, t= 79272.88694338493
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# valve open, t= 79489.71295639075
# Valve closes
# inlet is open
# inlet is open
# valve open, t= 79573.11208016114
# Valve closes

# %%
def system(t, y, params):
    T, P, n_mol = y
    P_open,P_close,P_amb, solar_constants,R_valve, A_Exposed, cloud_factor, T_amb,R, m, c, ii, jj, ff = params

    # Interpolate the solar_constants and T_amb
    solar_constants_func = interp1d(np.arange(len(solar_constants)), solar_constants, bounds_error=False, fill_value="extrapolate")
    interpolated_solar_constants = solar_constants_func(t)
    P_sun = interpolated_solar_constants * A_Exposed[ii, jj] * cloud_factor[ff] *dt

    P_amb_func = interp1d(np.arange(len(P_amb)), P_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_P_amb = P_amb_func(t)

    #Interpolate T_amb and calculate heat loss through radiation, Q_rad
    T_amb_func = interp1d(np.arange(len(T_amb)), T_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_T_amb = T_amb_func(t)
    Q_rad = e * sigma * A_exposed[ii,jj] * (T**4 - interpolated_T_amb**4)
    
    alpha_interpolated_func = interp1d(np.arange(len(T_amb)), alpha_hour[ii,jj,:], bounds_error=False, fill_value="extrapolate")
    interpolated_alpha = alpha_interpolated_func(t)
    Q_con = interpolated_alpha * A_exposed[ii,jj] * (T - interpolated_T_amb)

    
    #Valve is normally closed
    dT_dt = (P_sun-Q_rad-Q_con) / (m[ii, jj] * c[ii, jj])
    dP_dt = (n_mol*R*dT_dt)/V[ii,jj]
    dn_dt = 0


    #State 0: inlet and valve are closed
    if state_v == 0:
        if (P >= (interpolated_P_amb+P_open)):
            #Change state to open
            state_v = 1

            #Compute pressure changes 
            Q_tank = -(P - interpolated_P_amb) / R_valve #if P > interpolated_P_amb else 0 
        
            # Pressure drop is related to the volume out and the original volume 
            dP_dt += Q_tank / V[ii,jj]  # Change in pressure in tank
            dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
            print('valve open, t=', t)
            return [dT_dt, dP_dt,dn_dt]
        
        elif (P < (interpolated_P_amb-P_in)):
            # If inlet is open, change state to 2
            P = interpolated_P_amb
            print('inlet is open')
            return [dT_dt, dP_dt,dn_dt]

        else:    
            #Volume flow out of tank is pressure difference devided by the resistance of the valve 
            Q_tank = -(P - interpolated_P_amb) / R_valve #if P > interpolated_P_amb else 0 
            
            # Pressure drop is related to the volume out and the original volume 
            dP_dt += Q_tank / V[ii,jj]  # Change in pressure in tank
            dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
            print('valve open, t=', t)
            return [dT_dt, dP_dt,dn_dt]
               
    #State 1: Valve to actuator is open 
    if state_v ==1:
        Q_tank = (P - interpolated_P_amb) / R_valve #if P > interpolated_P_amb else 0 

        # Pressure drop is related to the volume out and the original volume 
        dP_dt -= Q_tank / V[ii,jj]  # Change in pressure in tank
        dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
        print('valve stayed open')
        state.append(1)
        if P < (interpolated_P_amb + P_close):
            #If pressure drops below closing pressure change state to closed
            state_v = 0
            print('Valve closes')
            return [dT_dt, dP_dt,dn_dt]


sol = solve_ivp(system, [t_start, t_span[1]], y0, dense_output=True, args=(params,),method='RK45',
    t_eval=np.linspace(t_start,t_span[1],nsampling))

# %%
# Calculate solar constants
#t = np.linspace(0, len(df['P_sun'].values), len(df['P_sun'].values))
solar_constants_func = interp1d(np.arange(len(df['P_sun'].values)), df['P_sun'].values, bounds_error=False, fill_value="extrapolate")
interpolated_solar_constants = solar_constants_func(t)

def interpolate_data(T, t, A_exposed, alpha_hour, T_amb,P_amb, ii, jj):
    # Interpolate T_amb
    T_amb_func = interp1d(np.arange(len(T_amb)), T_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_T_amb = T_amb_func(t)

    P_amb_func = interp1d(np.arange(len(P_amb)), P_amb, bounds_error=False, fill_value="extrapolate")
    interpolated_P_amb = P_amb_func(t)
    
    # Interpolate alpha_hour
    alpha_interpolated_func = interp1d(np.arange(len(T_amb)), alpha_hour[ii,jj,:], bounds_error=False, fill_value="extrapolate")
    interpolated_alpha = alpha_interpolated_func(t)
    
    Q_rad = e * sigma * A_exposed[ii,jj] * (T**4 - interpolated_T_amb**4)
    Q_con = interpolated_alpha * A_exposed[ii,jj] * (T - interpolated_T_amb)
    return Q_rad, Q_con, interpolated_P_amb,interpolated_T_amb

# %%
#Eval function
y1 = sol.sol(t)

Q_rad, Q_con,P_amb, T_amb = interpolate_data(y1[0,:], t, A_exposed, alpha_hour, df['T_amb'].values,df['P_amb'].values, ii, jj)
#n_mol = y[1,:] * V[ii,jj] / (R * y[0,:]) 
#Plot results 

fig, (ax1, ax3) = plt.subplots(2, 1, sharex=True,figsize=(10,6))  # Create two subplots sharing the same x-axis

# First subplot for temperature and solar constants
ax2 = ax1.twinx()  # Create a second y-axis for the first subplot
ax1.plot(t/3600, y[0,:]-K,color='red',label='$T_{vessel}$') 
ax1.plot(t/3600, T_amb-K,color='red', linestyle='--',label='$T_{amb}$') 
ax1.legend(loc='upper left')
ax1.set_ylabel('T [$C$]',color='red')
ax1.tick_params(axis='y', labelcolor='red')

ax2.plot(t/3600, interpolated_solar_constants, color='orange',label='P_sun',linestyle='--')
ax2.plot(t/3600, Q_rad/A[ii,jj], label='Q_rad', linestyle=':', color='orange')
ax2.plot(t/3600, Q_con/A[ii,jj], label='Q_con', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
ax2.set_ylabel('P [$Wm^{-2}$]', color='orange')
ax2.legend()

# Second subplot for pressure and moles
ax4 = ax3.twinx()  # Create a second y-axis for the second subplot
ax3.plot(t/3600, y[1,:]/1000, color='green',label='Vessel') 
ax3.plot(t/3600, P_amb/1000, color='green', linestyle='--',label='$P_{amb}$')
ax3.plot(t/3600, (P_amb+P_open)/1000, color='pink', linestyle='-.',label='$P_{open}$')
ax3.plot(t/3600, (P_amb+P_close)/1000, color='pink', linestyle='-.',label='$P_{close}$')
ax3.plot(t/3600, (P_amb-P_in)/1000, color='pink', linestyle='--',label='$P_{in}$')
ax3.set_ylabel('P [$kPa$]', color='green')
ax3.tick_params(axis='y', labelcolor='green')
ax3.legend(loc='upper left')

ax4.plot(t/3600, y[2,:], color='blue',linestyle=':')  # Plot n_mol on the second y-axis
ax4.set_ylabel('n [$mol$]', color='blue')
ax4.tick_params(axis='y', labelcolor='blue')
#ax4.set_ylim(0,n[ii,jj]*1.1)

#ax5.plot(t/3600, y[3,:], color='blue') #Plot if the valve = open or closed 
#ax5.set_ylim(-0.1,1.1)



#ax5.set_xlabel('Time [$h$]')

plt.xlim(0,24)
plt.show()

# %% [markdown]
# Solve system of ODE's

# %% [markdown]
# Plotting

# %%
plt.figure(figsize=(10,6))
plt.plot(state)
plt.title('State Plot')
plt.xlabel('Index')
plt.ylabel('State')
plt.show()
