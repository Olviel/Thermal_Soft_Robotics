# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import constants 
from scipy.interpolate import CubicSpline
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
import pandas as pd
import seaborn as sns
import itertools
from compute_alpha_hour import compute_alpha_hour
from joblib import load
from joblib import dump
import datetime

# %%
# Load weather data 

# specify the file path (use the actual path on your system)
file_path = 'Meteo_data/Weather_data_2023_7_6_n5.csv'

# read the CSV file into a DataFrame
df = pd.read_csv(file_path) #Data in seconds, T in K and P in Pa, windspeed in m/s, 0.1 meter above the ground

# Set time period
n_days = int(file_path[-5]) #Extract how many days are simulated in the file
df
# Out:
#                     t       T_amb     P_amb    v_wind  P_sun
# 0            0.000000  286.400000  101450.0  1.033567    0.0
# 1            0.999991  286.400083  101450.0  1.033597    0.0
# 2            1.999981  286.400167  101450.0  1.033627    0.0
# 3            2.999972  286.400250  101450.0  1.033657    0.0
# 4            3.999963  286.400333  101450.0  1.033687    0.0
# ...               ...         ...       ...       ...    ...
# 432000  431996.000037  290.300000  101760.0  1.033567    0.0
# 432001  431997.000028  290.300000  101760.0  1.033567    0.0
# 432002  431998.000019  290.300000  101760.0  1.033567    0.0
# 432003  431999.000009  290.300000  101760.0  1.033567    0.0
# 432004  432000.000000  290.300000  101760.0  1.033567    0.0
#
# [432005 rows x 5 columns]

# %%
from scipy.interpolate import UnivariateSpline
smoothing_factor=1
t=range(len(df['t']))
T_amb_spline = UnivariateSpline(df['t'], df['T_amb'], s=smoothing_factor)
P_amb_spline = UnivariateSpline(df['t'], df['P_amb'], s=smoothing_factor)
P_sun_spline = UnivariateSpline(df['t'], df['P_sun'], s=smoothing_factor)

# %%
plt.plot(t,T_amb_spline(t))
plt.show()
plt.plot(t,P_amb_spline(t))
plt.show()
plt.plot(t,P_sun_spline(t))
plt.show()

# %%
# %whos
# Out:
# Variable             Type                Data/Info
# --------------------------------------------------
# CubicSpline          type                <class 'scipy.interpolate._cubic.CubicSpline'>
# P_amb_spline         UnivariateSpline    <scipy.interpolate.fitpac<...>ct at 0x00000209E434D4F0>
# P_sun_spline         UnivariateSpline    <scipy.interpolate.fitpac<...>ct at 0x00000209E434DC40>
# T_amb_spline         UnivariateSpline    <scipy.interpolate.fitpac<...>ct at 0x00000209E933E700>
# UnivariateSpline     type                <class 'scipy.interpolate<...>tpack2.UnivariateSpline'>
# compute_alpha_hour   function            <function compute_alpha_h<...>ur at 0x00000209E7C31040>
# constants            module              <module 'scipy.constants'<...>\constants\\__init__.py'>
# datetime             module              <module 'datetime' from '<...>onda3\\lib\\datetime.py'>
# df                   DataFrame                               t    <...>[432005 rows x 5 columns]
# dump                 function            <function dump at 0x00000209E8182310>
# file_path            str                 Meteo_data/Weather_data_2023_7_6_n5.csv
# interp1d             type                <class 'scipy.interpolate.interpolate.interp1d'>
# itertools            module              <module 'itertools' (built-in)>
# load                 function            <function load at 0x00000209E8199B80>
# mdates               module              <module 'matplotlib.dates<...>s\\matplotlib\\dates.py'>
# n_days               int                 5
# np                   module              <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# pd                   module              <module 'pandas' from 'c:<...>es\\pandas\\__init__.py'>
# plt                  module              <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# smoothing_factor     int                 1
# sns                  module              <module 'seaborn' from 'c<...>s\\seaborn\\__init__.py'>
# solve_ivp            function            <function solve_ivp at 0x00000209E6F921F0>
# t                    range               range(0, 432005)

# %% [markdown]
# Simulation variables

# %%
#Vessel variables
#rho_vessel = 2.7e3 # aluminium [kg/m3]
rho_vessel = 1.455e3 # Pet [kg/m3] Source: https://plasticranger.com/density-of-pet-plastic/#:~:text=The%20density%20of%20PET%20plastic%20is%201.38%20g%2Fcm%C2%B3%20and,(1.2%20g%2Fcm3).
t_vessel = 0.5e-3 # Thickness [m]
#c_vessel = 890 #J/kg aluminium
c_vessel = 1030 #J/kg Pet Source: https://www.engineeringtoolbox.com/specific-heat-polymers-d_1862.html

#Assumptions
A_factor=0.5 #Assume half of the area of the vessel is exposed to sunlight 
e = 0.9 # emissvity factor black epoxy
alpha=100#[W/M^2K] Convection heat transfer coeficient
P_crit=1e3 #[pa] critical pressure where the hysterical valve opens
cloud_factor = np.linspace(0.1,1,2) # 1 = sunny, 0 = dark

# %% [markdown]
# Simulation constants

# %%
#Vessel properties 
D = np.linspace(0.05,0.3,2) #Diameter vessel
L = np.linspace(0.05,0.3,2) #Lenght vessel

# Create a 2-D grid for D and L
D, L = np.meshgrid(D, L)

# Now D and L are 2-D arrays containing all combinations of diameter and length
V = D**2/4*np.pi*L  # [m^3]
A = D*L + D**2/4*np.pi  # [m^2]

#Air 
rho_air=1.293 #kgm-3 
m_air = rho_air*V #[kg]
R = constants.R #J/K*molz ideal gas constant 
c_air = 718 #j/kg K constant volume
n_mass = 28.96747 #molar mass [g/mol]
n = m_air/n_mass #Amount of mol air 
sigma = constants.sigma #Boltzman constant 

cp = 1000 #J/kgK @ 300 K
cv = 718 #J/kgK @ 300k
y = cp/cv 
K = 273.15 #Kelvin 

#Combined properties
m_vessel = A*t_vessel*rho_vessel
m = m_vessel+m_air #kg
c = m_vessel/m*c_vessel+m_air/m*c_air #j/kg K 

# Find the dimensions of A_exposed
num_rows, num_cols = A.shape
A_exposed= A_factor*A

# Create an array for each hour in the day, converted to seconds
dt=1 # Second
day_length = n_days*24 * 60 * 60  # length of a day in seconds
time_steps = np.linspace(0, day_length, num=day_length // dt + n_days)  # time steps
hours = np.arange(n_days*24)*60*60

# %% [markdown]
# Heat transfer coefficient alpha as function of windspeed and cilinder diameter

# %%
#Interpolate the hourly wind data to convection per second
alpha_hour = compute_alpha_hour(num_rows, num_cols, D, df['v_wind'], time_steps, hours)

# %%
# Fit PV curve

# Data from Shibo groupmeeting slides pneunet actuator with h = \inf 
v_fit = np.array([0, 5, 10, 15, 20, 25, 30, 35])*1e-6+1e-4 #[m3] data in mL converted to L
p_fit = np.array([0, 9, 16, 21, 24, 27, 28, 29])*1000 #[pa] data in kpa converted to pa

# Create cubic spline
volume_act = interp1d(p_fit, v_fit, kind='slinear',bounds_error=False, fill_value="extrapolate") #L/Pa

# Plot
p_vals = np.linspace(p_fit[0], p_fit[-1], 10)
v_vals = volume_act(p_vals)

plt.figure(figsize=(8, 6))
plt.plot(p_vals/1000, v_vals*1e6, label='Cubic Interpolation')
plt.scatter(p_fit/1000, v_fit*1e6, color='red', label='Data')
plt.legend()
plt.xlabel('p [kPa]')
plt.ylabel('v [ml]')
plt.title('Cubic Interpolation for v(p)')
plt.show()

p = 10e3  # For example
v = volume_act(0)
print(v)
# Out:
# 0.0001

# %% [markdown]
# Define system of ODE's

# %%
def system(t, y, params):
    T, P, P_act, n_mol = y
    P_open,P_close,P_amb, solar_constants,R_in,R_valve,R_act, A_Exposed, cloud_factor, T_amb,R, m, c, ii, jj, ff = params
    
    #Make the state of the valve a global variable
    global state_v

    P_sun = P_sun_spline(t) * A_Exposed[ii, jj] * cloud_factor[ff] *dt
    interpolated_P_amb = P_amb_spline(t)    
    interpolated_T_amb = T_amb_spline(t)
    Q_rad = e * sigma * A_exposed[ii,jj] * (T**4 - interpolated_T_amb**4)
    
    #Interpolate alpha from hours to seconds
    alpha_interpolated_func = interp1d(np.arange(len(T_amb)), alpha_hour[ii,jj,:], bounds_error=False, fill_value="extrapolate")
    interpolated_alpha = alpha_interpolated_func(t)
    Q_con = interpolated_alpha * A_exposed[ii,jj] * (T - interpolated_T_amb)

    P_act_max = 1.2*interpolated_P_amb
    if np.isinf(P_act):
        print("Warning: P_act reached infinity at time t=", t)
                
    if P_act > P_act_max:
        P_act = P_act_max
    elif P_act < -P_act_max:  # If you want to limit negative values too
        P_act = -P_act_max


    #Compute pressure change in actuator
    
    if P>P_open+P_act:
        if state_v==1:
            Q_tank = 0       
        else:
            Q_tank=0
    else: 
        Q_tank=0
    
    
    #Compute pressure change in vessel due to temperature increase
    dT_dt = (P_sun-Q_rad-Q_con) / (m[ii, jj] * c[ii, jj])
    dP_dt = (n_mol*R*dT_dt)/V[ii,jj]    

    #Reset vars for new itteration
    dn_dt = 0
    Q_act = 0#(P_act - interpolated_P_amb) / R_act 
    dP_act_dt = 0#((Q_tank - Q_act) / volume_act(P_act-interpolated_P_amb)) 
    Q_tank=0 
 
 
    #State 0: inlet and valve are closed
    if state_v == 0:        
        if (P > (interpolated_P_amb+P_open)):
            #Change state to open
            state_v = 1
            print('valve opens, t=', t)
            return [dT_dt, dP_dt,dP_act_dt,dn_dt]
        
        elif (P < (interpolated_P_amb-P_in)):
            # If inlet is open, change state to 2
            state_v=2
            P = interpolated_P_amb
            dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
            
            print('inlet is open')
            return [dT_dt, dP_dt,dP_act_dt,dn_dt]

        else:
                   
            dP_act_dt = compute_dP_act_dt(P_act, interpolated_P_amb, R_act, volume_act)    

            return [dT_dt, dP_dt,dP_act_dt,dn_dt]
               
    #State 1: Valve to actuator is open 
    if state_v ==1:
        if P < (P_act + P_close):
            #If pressure drops below closing pressure change state to closed
            state_v = 0
            
            print('Valve closes')            
            return [dT_dt, dP_dt,dP_act_dt,dn_dt]                      
        
        else: 
        #Compute pressure changes 
            Q_tank += (P - P_act) / R_valve #if P > interpolated_P_amb else 0 
            dP_dt -= Q_tank / V[ii,jj]  # Change in pressure in tank
            Q_act = (P_act - interpolated_P_amb) / R_act  
            dP_act_dt = ((Q_tank - Q_act) / volume_act(P_act-interpolated_P_amb))
            dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)          
            print('valve stayed open t= ',t)                   
                       
        return [dT_dt, dP_dt,dP_act_dt,dn_dt]          
        
        

    # state2: inlet is open
    if state_v ==2:
        
        if P > 0.999*interpolated_P_amb:
            #Inlet closes again 
            state_v=0
            
            print('inlet closed')
            return [dT_dt, dP_dt,dP_act_dt,dn_dt]
        else:
            # Otherwise it stays open
            Q_tank += (P - interpolated_P_amb) / R_in 
            

            # Pressure drop is related to the volume out and the original volume 
            dP_dt -= Q_tank / V[ii,jj] 
                
            
            dn_dt += (V[ii,jj]/T)*(dP_dt/R-P*dT_dt/T)
            print('inlet is open')
            
            return [dT_dt, dP_dt,dP_act_dt,dn_dt]
    else:
        print('else2')
        return [dT_dt, dP_dt,dP_act_dt,dn_dt] 


def compute_dP_act_dt(P_act, interpolated_P_amb, R_act, volume_act):
    difference = P_act - interpolated_P_amb
    Q_act = difference / R_act
    
    if difference > 1e-6:
        return -abs(Q_act) / volume_act(difference)
    elif difference < -1e-6:
        return abs(Q_act) / volume_act(0)
    else:
        return 0

#Define simulation settings
t_span = [0, len(df['P_sun'].values)]  # start and end time
current_time = datetime.datetime.now().strftime('%Y%m%d_%H%M%S') #Define current time for saving

#Set limit pressures where valves open 
P_open = 2e3 #pa 
P_close = 1e3 #pa
P_in = 0.3e3 #pa

R_valve=1/12 # Resistance of first valve, Pa.s/m^3
R_in = 1/12
R_act = 5000
state_v = 0 #Valve starts normally closed
params_base = [P_open,P_close,df['P_amb'].values,df['P_sun'].values, R_in,R_valve,R_act,A_exposed, cloud_factor,df['T_amb'].values, R,m, c ]

# Use itertools.product to simplify nested loops

for ii, jj, ff in itertools.product(range(len(D)), range(len(L)), range(len(cloud_factor))):
    #ii=jj=1
    params = params_base + [ii, jj, ff]
    print(ii,jj,ff)
    
    # Define initial conditions
    n0 = df['P_amb'][0]*V[ii,jj]/(R*df['T_amb'][0])
    y0 = [df['T_amb'][0], df['P_amb'][0], df['P_amb'][0], n0]
    
    t_start= t_span[0]
    nsampling = int(1*t_span[1])
    
    print(y0,t_start)
    sol = solve_ivp(system, [t_start, t_span[1]], y0, dense_output=True, args=(params,),method='RK45',
            t_eval=np.linspace(t_start,t_span[1]), rtol=1e-5, atol=1e-7)
      
    print(sol.message)
    t= sol.t
    y= sol.y   
    dump(sol,f"..\\Saved_solutions\{file_path[-15:-4]}_{current_time}_{ii}_{jj}_{ff}_sol.joblib")
      
    break

 
# Writing used vars to a txt file
with open(f"..\\Saved_solutions\\variables_{file_path[-15:-4]}_{current_time}.txt", 'w') as file:
    file.write(f"P_open = {P_open} [Pa]\n")
    file.write(f"P_close= {P_close} [Pa]\n")
    file.write(f"P_in= {P_in} [Pa]\n")
    file.write(f"R_valve = {R_valve}\n")
    file.write(f"R_act = {R_act}\n")
    file.write(f"R_in = {R_in}\n")
# Out:
# 0 0 0
# [286.4, 101450.0, 101450.0, 0.004182584724938929] 0
# inlet is open
# inlet closed
# valve opens, t= 37564.29186170056
# valve stayed open t=  37564.29186170056
# valve stayed open t=  37562.559574980754
# Valve closes
# valve opens, t= 37562.77611082073
# valve stayed open t=  37562.80819020443
# valve stayed open t=  37562.848289434056
# Valve closes
# valve opens, t= 37564.91275331742
# valve stayed open t=  37565.08599927187
# valve stayed open t=  37565.30255671493
# Valve closes
# valve opens, t= 37564.76694546262
# valve stayed open t=  37565.083844932735
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.25990631044
# valve stayed open t=  37564.32328620447
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.234554352835
# valve stayed open t=  37564.24582188955
# valve stayed open t=  37564.25990631044
# Valve closes
# valve opens, t= 37564.23455435283
# valve stayed open t=  37564.259906310435
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.224413569784
# valve stayed open t=  37564.22892058447
# valve stayed open t=  37564.23455435283
# Valve closes
# valve opens, t= 37564.22441356979
# valve stayed open t=  37564.234554352835
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.22035725657
# valve stayed open t=  37564.22216006245
# valve stayed open t=  37564.22441356979
# Valve closes
# valve opens, t= 37564.220357256585
# valve stayed open t=  37564.224413569806
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.218734731294
# valve stayed open t=  37564.21945585365
# valve stayed open t=  37564.220357256585
# Valve closes
# valve opens, t= 37564.21873473131
# valve stayed open t=  37564.2203572566
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.2164631959
# valve stayed open t=  37564.21808572119
# valve stayed open t=  37564.21837417013
# valve stayed open t=  37564.21873473131
# Valve closes
# valve opens, t= 37564.21626849286
# valve stayed open t=  37564.21633339387
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.216254070416
# valve stayed open t=  37564.21626849286
# Valve closes
# valve opens, t= 37564.21625831335
# valve stayed open t=  37564.21628821897
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.216251667654
# valve stayed open t=  37564.21625831335
# Valve closes
# valve opens, t= 37564.21626273608
# valve stayed open t=  37564.21627879458
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.216256312684
# valve stayed open t=  37564.21625916753
# valve stayed open t=  37564.21626273608
# Valve closes
# valve opens, t= 37564.216264821735
# valve stayed open t=  37564.216273372396
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.21625114068
# valve stayed open t=  37564.216252850805
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.21624843749
# valve stayed open t=  37564.21624879603
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.21624800945
# valve stayed open t=  37564.21624815396
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 37564.2162480024
# valve stayed open t=  37564.216248472374
# valve stayed open t=  37564.216248555924
# valve stayed open t=  37564.21624866036
# valve stayed open t=  37564.21624866036
# valve stayed open t=  37564.21624884835
# valve stayed open t=  37564.21624894235
# valve stayed open t=  37564.216249412326
# valve stayed open t=  37564.216249495876
# valve stayed open t=  37564.216249600315
# valve stayed open t=  37564.216249600315
# valve stayed open t=  37564.21625043417
# valve stayed open t=  37564.2162508511
# Valve closes
# valve opens, t= 41372.4606670118
# valve stayed open t=  41373.37216828555
# valve stayed open t=  41373.53421295644
# valve stayed open t=  41373.73676879505
# Valve closes
# valve opens, t= 41372.35128685895
# valve stayed open t=  41372.3877469099
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 41372.33670283858
# valve stayed open t=  41372.34318462541
# valve stayed open t=  41372.35128685895
# Valve closes
# valve opens, t= 41372.33670283856
# valve stayed open t=  41372.35128685894
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t=
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 114573.48399615588
# valve stayed open t=  114573.48399659139
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 114573.48399657164
# valve stayed open t=  114573.48399671461
# valve stayed open t=  114573.48399689334
# valve stayed open t=  114573.48399689334
# valve stayed open t=  114573.48399547343
# valve stayed open t=  114573.48399556775
# valve stayed open t=  114573.48399603924
# valve stayed open t=  114573.48399612306
# valve stayed open t=  114573.48399622783
# valve stayed open t=  114573.48399622783
# valve stayed open t=  114573.48399641643
# valve stayed open t=  114573.48399651074
# valve stayed open t=  114573.48399698224
# valve stayed open t=  114573.48399706605
# valve stayed open t=  114573.48399717083
# valve stayed open t=  114573.48399717083
# valve stayed open t=  114573.48399802265
# Valve closes
# valve opens, t= 114573.48400057814
# valve stayed open t=  114573.48400095673
# valve stayed open t=  114573.48400142997
# valve stayed open t=  114573.48400142997
# valve stayed open t=  114573.48399757285
# valve stayed open t=  114573.48399777387
# Valve closes
# valve opens, t= 117686.18007511311
# valve stayed open t=  117687.0449036612
# valve stayed open t=  117687.19865095864
# valve stayed open t=  117687.39083508044
# Valve closes
# valve opens, t= 117686.07629568734
# valve stayed open t=  117686.11088882927
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 117686.06245843056
# valve stayed open t=  117686.06860832247
# valve stayed open t=  117686.07629568734
# Valve closes
# valve opens, t= 117686.06245843059
# valve stayed open t=  117686.07629568737
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 117686.04031881975
# valve stayed open t=  117686.04308627111
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 117686.03644438785
# valve stayed open t=  117686.0392118392
# valve stayed open t=  117686.03970383057
# valve stayed open t=  117686.04031881975
# Valve closes
# valve opens, t= 117686.0361122937
# valve stayed open t=  117686.03622299175
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 117686.0361122937
# valve stayed open t=  117686.0361122937
# valve stayed open t=  117686.03590103319
# Valve closes
# valve opens, t= 117686.03593143998
# valve stayed open t=  117686.03593594469
# valve stayed open t=  117686.03594157558
# valve stayed open t=  117686.03594157558
# valve stayed open t=  117686.03589292472
# Valve closes
# valve opens, t= 117686.03589900606
# valve stayed open t=  117686.03589990702
# valve stayed open t=  117686.03590103319
# valve stayed open t=  117686.03590103319
# valve stayed open t=  117686.03589134716
# valve stayed open t=  117686.03589157196
# valve stayed open t=  117686.03589269589
# valve stayed open t=  117686.03589289568
# valve stayed open t=  117686.03589314545
# valve stayed open t=  117686.03589314545
# valve stayed open t=  117686.03589125967
# valve stayed open t=  117686.03589144073
# valve stayed open t=  117686.03589234594
# valve stayed open t=  117686.03589250686
# valve stayed open t=  117686.03589270802
# valve stayed open t=  117686.03589270802
# valve stayed open t=  117686.03589305036
# valve stayed open t=  117686.03589322153
# Valve closes
# valve opens, t= 120512.0844742385
# valve stayed open t=  120512.85313370566
# valve stayed open t=  120512.98978427761
# valve stayed open t=  120513.16059749253
# Valve closes
# valve opens, t= 120511.99223510244
# valve stayed open t=  120512.02298148113
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 120511.97993655097
# valve stayed open t=  120511.98540257385
# valve stayed open t=  120511.99223510244
# Valve closes
# valve opens, t= 120511.97993655097
# valve stayed open t=  120511.99223510244
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t=
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.8263159101
# valve stayed open t=  123623.82662481356
# valve stayed open t=  123623.82701094287
# Valve closes
# valve opens, t= 123623.8263159101
# valve stayed open t=  123623.82701094287
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.826037897
# valve stayed open t=  123623.82616145838
# valve stayed open t=  123623.8263159101
# Valve closes
# valve opens, t= 123623.82542626816
# valve stayed open t=  123623.82545098044
# valve stayed open t=  123623.82548187078
# Valve closes
# valve opens, t= 123623.82542626816
# valve stayed open t=  123623.82548187078
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.82540402711
# valve stayed open t=  123623.82541391203
# valve stayed open t=  123623.82542626816
# Valve closes
# valve opens, t= 123623.8254040271
# valve stayed open t=  123623.82542626814
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.82539513068
# valve stayed open t=  123623.82539908464
# valve stayed open t=  123623.8254040271
# Valve closes
# valve opens, t= 123623.82540094206
# valve stayed open t=  123623.82541129133
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.82539680236
# valve stayed open t=  123623.82539864222
# valve stayed open t=  123623.82540094206
# valve stayed open t=  123623.82540094206
# valve stayed open t=  123623.82538179767
# valve stayed open t=  123623.82538257472
# valve stayed open t=  123623.82538646004
# valve stayed open t=  123623.82538715076
# valve stayed open t=  123623.82538801417
# Valve closes
# valve opens, t= 123623.82539255089
# valve stayed open t=  123623.82540485825
# valve stayed open t=  123623.82540704621
# valve stayed open t=  123623.82540978119
# Valve closes
# valve opens, t= 123623.82539173044
# valve stayed open t=  123623.82539255093
# valve stayed open t=  123623.82539255093
# valve stayed open t=  123623.82538584656
# valve stayed open t=  123623.8253861866
# valve stayed open t=  123623.82538788678
# valve stayed open t=  123623.82538818904
# valve stayed open t=  123623.82538856687
# Valve closes
# valve opens, t= 123623.82539234919
# valve stayed open t=  123623.82539414486
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 123623.8253917167
# valve stayed open t=  123623.82539204546
# valve stayed open t=  123623.82539245642
# valve stayed open t=  123623.82539245642
# valve stayed open t=  123623.82538913519
# valve stayed open t=  123623.82538932389
# valve stayed open t=  123623.8253902673
# valve stayed open t=  123623.82539043501
# valve stayed open t=  123623.82539064466
# valve stayed open t=  123623.82539064466
# valve stayed open t=  123623.82539099037
# valve stayed open t=  123623.82539116323
# Valve closes
# valve opens, t= 127831.53832604081
# valve stayed open t=  127831.67673206287
# valve stayed open t=  127831.84973959046
# Valve closes
# valve opens, t= 127831.31329309316
# valve stayed open t=  127831.51219016897
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 127831.26909374299
# valve stayed open t=  127831.31329309316
# Valve closes
# valve opens, t= 127831.31329309319
# valve stayed open t=  127831.71108724484
# valve stayed open t=  127831.78180620514
# valve stayed open t=  127831.8702049055
# Valve closes
# valve opens, t= 127831.26555779499
# valve stayed open t=  127831.28146956106
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 127831.25919308857
# valve stayed open t=  127831.26202184698
# valve stayed open t=  127831.26555779499
# Valve closes
# valve opens, t= 127831.25919308855
# valve stayed open t=  127831.26555779498
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 127831.25664720598
# valve stayed open t=  127831.25777870935
# valve stayed open t=  127831.25919308855
# Valve closes
# valve opens, t= 127831.25664720598
# valve stayed open t=  127831.25919308855
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t=
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 384883.09509078314
# valve stayed open t=  384883.0950909943
# valve stayed open t=  384883.09509125835
# valve stayed open t=  384883.09509125835
# valve stayed open t=  384883.09508914244
# valve stayed open t=  384883.09508927254
# valve stayed open t=  384883.09508992307
# valve stayed open t=  384883.0950900387
# valve stayed open t=  384883.09509018325
# valve stayed open t=  384883.09509018325
# valve stayed open t=  384883.09509044344
# valve stayed open t=  384883.09509057354
# valve stayed open t=  384883.09509122407
# valve stayed open t=  384883.0950913397
# valve stayed open t=  384883.09509148425
# valve stayed open t=  384883.09509148425
# Valve closes
# valve opens, t= 393735.53574806347
# valve stayed open t=  393735.71501078695
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.28478025063
# valve stayed open t=  393735.4640429741
# valve stayed open t=  393735.4959119027
# valve stayed open t=  393735.53574806347
# Valve closes
# valve opens, t= 393735.2632687238
# valve stayed open t=  393735.2704392327
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.26040052023
# valve stayed open t=  393735.2616752774
# valve stayed open t=  393735.2632687238
# Valve closes
# valve opens, t= 393735.2604005202
# valve stayed open t=  393735.26326872373
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.25925323874
# valve stayed open t=  393735.2597631416
# valve stayed open t=  393735.2604005202
# Valve closes
# valve opens, t= 393735.2592532388
# valve stayed open t=  393735.26040052023
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.2574175885
# valve stayed open t=  393735.2576470448
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.25732580596
# valve stayed open t=  393735.25736659823
# valve stayed open t=  393735.2574175885
# Valve closes
# valve opens, t= 393735.2573258061
# valve stayed open t=  393735.2574175886
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.25728909305
# valve stayed open t=  393735.25730540993
# valve stayed open t=  393735.2573258061
# Valve closes
# valve opens, t= 393735.2572890931
# valve stayed open t=  393735.25732580613
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.2572744079
# valve stayed open t=  393735.25728093466
# valve stayed open t=  393735.2572890931
# Valve closes
# valve opens, t= 393735.2572744079
# valve stayed open t=  393735.2572890931
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.2572685338
# valve stayed open t=  393735.25727114454
# valve stayed open t=  393735.2572744079
# valve stayed open t=  393735.2572744079
# valve stayed open t=  393735.25724672974
# valve stayed open t=  393735.25724757585
# valve stayed open t=  393735.2572518065
# valve stayed open t=  393735.2572525586
# valve stayed open t=  393735.25725349877
# Valve closes
# valve opens, t= 393735.25727000216
# valve stayed open t=  393735.25727222126
# valve stayed open t=  393735.2572749951
# valve stayed open t=  393735.2572749951
# valve stayed open t=  393735.2572516416
# valve stayed open t=  393735.2572524472
# valve stayed open t=  393735.25725647516
# valve stayed open t=  393735.25725719123
# valve stayed open t=  393735.25725808635
# Valve closes
# valve opens, t= 393735.25726241875
# valve stayed open t=  393735.2572748071
# valve stayed open t=  393735.2572770094
# valve stayed open t=  393735.2572797624
# Valve closes
# valve opens, t= 393735.2572609059
# valve stayed open t=  393735.25726156373
# valve stayed open t=  393735.257262386
# valve stayed open t=  393735.257262386
# valve stayed open t=  393735.25725569203
# valve stayed open t=  393735.2572560452
# valve stayed open t=  393735.2572578109
# valve stayed open t=  393735.2572581248
# valve stayed open t=  393735.2572585172
# Valve closes
# valve opens, t= 393735.25726233295
# valve stayed open t=  393735.25726416975
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 393735.2572616611
# valve stayed open t=  393735.25726199464
# valve stayed open t=  393735.2572624115
# valve stayed open t=  393735.2572624115
# valve stayed open t=  393735.2572590415
# valve stayed open t=  393735.2572592326
# valve stayed open t=  393735.257260188
# valve stayed open t=  393735.25726035784
# valve stayed open t=  393735.2572605701
# valve stayed open t=  393735.2572605701
# valve stayed open t=  393735.25726091705
# valve stayed open t=  393735.25726109045
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419842.59294049424
# valve stayed open t=  419842.7942412007
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.771633612
# valve stayed open t=  419841.8521538946
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.2563038032
# valve stayed open t=  419841.2724078597
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.1532378414
# valve stayed open t=  419841.1564586527
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.1400969312
# valve stayed open t=  419841.14138525573
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.1348405673
# valve stayed open t=  419841.13535589713
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.1327380219
# valve stayed open t=  419841.13294415385
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.1318970034
# valve stayed open t=  419841.1319794562
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 419841.13165021146
# valve stayed open t=  419841.131692337
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420545.39279208647
# valve stayed open t=  420545.55803980876
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.7185813796
# valve stayed open t=  420544.78468046855
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.4488970965
# valve stayed open t=  420544.47533673205
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.2553589643
# valve stayed open t=  420544.25641654973
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.2510440161
# valve stayed open t=  420544.2514670503
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.24794740573
# valve stayed open t=  420544.2479643271
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 420544.2478862706
# valve stayed open t=  420544.24789384566
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428219.2589545078
# valve stayed open t=  428219.53730422474
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428218.12328766263
# valve stayed open t=  428218.23462754936
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.6690209248
# valve stayed open t=  428217.7135568795
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.3839908148
# valve stayed open t=  428217.3928980057
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.34764947573
# valve stayed open t=  428217.3512123521
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.33311294013
# valve stayed open t=  428217.3345380907
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.3239919766
# valve stayed open t=  428217.32427700673
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.3221677839
# valve stayed open t=  428217.32222478994
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.32204292336
# valve stayed open t=  428217.32207671803
# Valve closes
# inlet is open
# inlet is open
# inlet closed
# valve opens, t= 428217.32182663755
# valve stayed open t=  428217.3218333965
# Valve closes
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet is open
# inlet closed
# The solver successfully reached the end of the integration interval.

# %%
#Load old solution
#sol = load('..\\Saved_solutions\sol.joblib')
#t=sol.t
#y=sol.y

# %%
#Set necesarry variables for plotting
#ii=jj=ff=0
#P_open=2e3
#P_close =1e3

# %%
# Calculate solar constants
#t = np.linspace(0, len(df['P_sun'].values), len(df['P_sun'].values))
solar_constants_func = interp1d(np.arange(len(df['P_sun'].values)), df['P_sun'].values, bounds_error=False, fill_value="extrapolate")
interpolated_solar_constants = solar_constants_func(t)

def interpolate_data(T, t, A_exposed, alpha_hour, T_amb,P_amb, ii, jj):
    # Interpolate T_amb
    #T_amb_func = interp1d(np.arange(len(T_amb)), T_amb, bounds_error=False, fill_value="extrapolate")
    #interpolated_T_amb = T_amb_func(t)
    interpolated_T_amb=T_amb_spline(t)
    

    #P_amb_func = interp1d(np.arange(len(P_amb)), P_amb, bounds_error=False, fill_value="extrapolate")
    #interpolated_P_amb = P_amb_func(t)
    interpolated_P_amb = P_amb_spline(t)
    
    # Interpolate alpha_hour
    alpha_interpolated_func = interp1d(np.arange(len(T_amb)), alpha_hour[ii,jj,:], bounds_error=False, fill_value="extrapolate")
    interpolated_alpha = alpha_interpolated_func(t)
    
    Q_rad = e * sigma * A_exposed[ii,jj] * (T**4 - interpolated_T_amb**4)
    Q_con = interpolated_alpha * A_exposed[ii,jj] * (T - interpolated_T_amb)
    return Q_rad, Q_con, interpolated_P_amb,interpolated_T_amb

#Eval function
y1 = sol.sol(t)

Q_rad, Q_con,P_amb, T_amb = interpolate_data(y1[0,:], t, A_exposed, alpha_hour, df['T_amb'].values,df['P_amb'].values, ii, jj)
#n_mol = y[1,:] * V[ii,jj] / (R * y[0,:]) 
#Plot results 

fig, (ax1, ax3) = plt.subplots(2, 1, sharex=True,figsize=(10,6))  # Create two subplots sharing the same x-axis

# First subplot for temperature and solar constants
ax2 = ax1.twinx()  # Create a second y-axis for the first subplot
ax1.plot(t/3600, y[0,:]-K,color='red',label='$T_{vessel}$') 
ax1.plot(t/3600, T_amb_spline(t)-K,color='red', linestyle='--',label='$T_{amb}$') 
ax1.legend(loc='upper left')
ax1.set_ylabel('T [$\\circ C$]',color='red')
ax1.tick_params(axis='y', labelcolor='red')

ax2.plot(t/3600, P_sun_spline(t), color='yellow',label='P_sun',linestyle='--')
ax2.plot(t/3600, Q_rad/A[ii,jj], label='Q_rad', linestyle=':', color='orange')
ax2.plot(t/3600, Q_con/A[ii,jj], label='Q_con', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
ax2.set_ylabel('P [$Wm^{-2}$]', color='orange')
ax2.legend()

# Second subplot for pressure and moles
ax4 = ax3.twinx()  # Create a second y-axis for the second subplot
ax3.plot(t/3600, y[1,:]/1000, color='green',label='Vessel') 
ax3.plot(t/3600, y[2,:]/1000, color='red',label='Act') 
ax3.plot(t/3600, P_amb_spline(t)/1000, color='green', linestyle='--',label='$P_{amb}$')
ax3.plot(t/3600, (y[2,:]+P_open)/1000, color='pink', linestyle='-.',label='$P_{open}$')
#ax3.plot(t/3600, (y[2,:]+P_close)/1000, color='pink', linestyle='-.',label='$P_{close}$')
#ax3.plot(t/3600, (P_amb-P_in)/1000, color='pink', linestyle='--',label='$P_{in}$')
ax3.set_ylabel('P [$kPa$]', color='green')
ax3.tick_params(axis='y', labelcolor='green')
ax3.legend(loc='upper left')

ax4.plot(t/3600, y[-1,:], color='blue',linestyle=':')  # Plot n_mol on the second y-axis
ax4.set_ylabel('n [$mol$]', color='blue')
ax4.tick_params(axis='y', labelcolor='blue')
#ax4.set_ylim(0,n[ii,jj]*1.1)

#ax5.plot(t/3600, y[2,:], color='green',label='P_act') 
#ax5.plot(t/3600, P_amb_spline(t), color='blue',label='P_amb') 
#ax5.set_ylim(-0.1,1.1)
#ax5.legend()
#ax5.set_xlabel('Time [$h$]')

plt.xlim(0,n_days*24)
#plt.savefig(f"..\\figures\\{file_path[-15:-4]}_{current_time}.svg", format="svg")
plt.show()

# %%
# Out:
# 0.01884955592153876
